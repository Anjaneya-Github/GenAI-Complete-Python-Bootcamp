# %% [markdown]
# #### Working With File Paths
# When working with files in Python, handling file paths correctly is crucial to ensure your code works across different operating systems and environments. Python provides several modules and functions for working with file paths effectively.

# %%
#### Using the os module
import os
cwd=os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is d:\Anjaneya workspace\Adv AI ML\KN-Complete Python With DSA Bootcamp + LEETCODE Exercises\File Handling

# %%
## create a new directory
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# Directory 'package' create

# %%
## Listing Files And Directories
items=os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'examples.bin', 'package']

# %%
### Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\Anjaneya workspace\Adv AI ML\KN-Complete Python With DSA Bootcamp + LEETCODE Exercises\File Handling\folder\file.txt

# %%
path='example1.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'example1.txt' does not exists

# %%
#Checking if a Path is a File or Directory
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example.txt' is a file.

# %%
## Getting the absolute path
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Anjaneya workspace\Adv AI ML\KN-Complete Python With DSA Bootcamp + LEETCODE Exercises\File Handling\example.txt

# %%
#Closing a file

try:
   f=open("example.txt")

finally:
   f.close()

# %%
with open ("example.txt",encoding ='utf-8') as f:
    content = f.read(11)
    print(content)
# Out:
# Hello world

# %%
content_to_write = "This is some text encoded in UTF-8."

# Use 'w' for write mode
with open("example.txt", "w", encoding="utf-8") as f:
    f.write(content_to_write)

    print(content_to_write)
# Out:
# This is some text encoded in UTF-8.

# %%
additional_content = "\nThis line is appended."

# Use 'a' for append mode
with open("example.txt", "a", encoding="utf-8") as f:
    f.write(additional_content)

    print(content_to_write)
# Out:
# This is some text encoded in UTF-8.

# %%
f=open("test.txt","w")
f.write("this is first file\n")
f.write("contains two lines\n")
# Out:
# 19

# %%
f=open("test.txt","r")
f.read()
# Out:
# 'this is first file\ncontains two lines\n'

# %%
f=open("test.txt","r")
f.read(10)
# Out:
# 'this is fi'

# %%
f=open("test.txt","r")
print(f.read())
# Out:
# this is first file
# contains two lines

# %%
f.seek(0)
for line in f:
    print(line)
# Out:
# this is first file
#
# contains two lines

# %%
f.seek(0)
f.readlines() # the readlines() method returns a list of remaining lines of the entire file.
# Out:
# ['this is first file\n', 'contains two lines\n']

# %%
f.close()

# %%
import os
os. rename ("test.txt","sample.txt")

# %%
f=open ("sample.txt","r")
f.readline()
# Out:
# 'this is first file\n'

# %%
f.readlines()
# Out:
# ['contains two lines\n']

# %%
f.close()

# %%
os.remove("sample.txt")

# %%
f=open("test.txt","w")
f.write("this is first file\n")
f.write("contains two lines\n")
# Out:
# 19

# %%
import shutil

os.mkdir("test1")
os.chdir('./test1')
f=open ("testfile.txt","w")
f.write("Hello world")
os.chdir("../")

# %%
f.close()

# %%
shutil.rmtree('test1') #remove and non-empty directory
